# %% [markdown]
# # 18. [OKCupid Date-A-Scientist](https://www.codecademy.com/paths/data-science/tracks/dscp-machine-learning-portfolio-project/modules/dscp-okcupid-date-a-scientist/kanban_projects/okcupid-date-a-scientist-portfolio-project)

# %% [markdown]
# <a id='Table_of_Contents'></a>

# %% [markdown]
# ## Table of Contents
#
#
# #### [Introduction](#Introduction)
#
# &emsp;&emsp;[Overview](#Overview)<br>
# &emsp;&emsp;[Setup](#Setup)<br>
# &emsp;&emsp;[Resources](#Resources)<br>
#
# #### [Project Tasks](#Project_Tasks)
#
# &emsp;&emsp;[Project Setup](#Project_Setup)<br>
# &emsp;&emsp;[Setting up your Git Repository](#Setting_up_your_Git_Repository)<br>
# &emsp;&emsp;[Project Scoping](#Project_Scoping)<br>
# &emsp;&emsp;[Select ML-Solvable Problem](#Select_ML-Solvable_Problem)<br>
# &emsp;&emsp;[Load and Check Data](#Load_and_Check_Data)<br>
# &emsp;&emsp;[Explore and Explain Data](#Explore_and_Explain_Data)<br>
# &emsp;&emsp;[Preprocess Data](#Preprocess_Data)<br>
# &emsp;&emsp;[Build Model(s)](#Build_Model(s))<br>
# &emsp;&emsp;[Evaluate Model(s)](#Evaluate_Model(s))<br>
# &emsp;&emsp;[Conclusions](#Conclusions)<br>
# &emsp;&emsp;[Next Steps](#Next_Steps)<br>
# &emsp;&emsp;[Create a Slide Deck](#Create_a_Slide_Deck)<br>

# %% [markdown]
# <a id='Introduction'></a>

# %% [markdown]
# ## Introduction

# %% [markdown]
# <a id='Overview'></a>

# %% [markdown]
# ## 1. Overview
#
# In recent years, there has been a massive rise in the usage of dating apps to find love. Many of these apps use sophisticated data science techniques to recommend possible matches to users and to optimize the user experience. These apps give us access to a wealth of information that we’ve never had before about how different people experience romance.
#
# In this portfolio project, you will analyze some data from OKCupid, an app that focuses on using multiple choice and short answers to match users.
#
# You will also create a presentation about your findings from this OKCupid dataset.
#
# The purpose of this project is to practice formulating questions and implementing machine learning techniques to answer those questions. However, the questions you ask and how you answer them are entirely up to you.
#
# We’re excited to see the different topics you explore.
#
#
# ### Example Project
#
# [OKCupid Date-A-Scientist Example Project](https://content.codecademy.com/PRO/paths/data-science/OKCupid-Date-A-Scientist-Solution.zip)
#
# ### Project Objectives:
#
# + Complete a project to add to your portfolio
# + Use Jupyter Notebook to communicate findings
# + Build, train, and evaluate a machine learning mode
#
# ### Prerequisites:
#
# + Natural Language Processing
# + Supervised Machine Learning
# + Unsupervised Machine Learning
#
# [Table of Contents](#Table_of_Contents)

# %% [markdown]
# <a id='Setup'></a>

# %% [markdown]
# ## 2. Setup
#
# ### Necessary Files:
#
# Click [this link](https://content.codecademy.com/PRO/paths/data-science/OKCupid-Date-A-Scientist-Starter.zip) to download a zip file with the necessary starter code and design assets. Note that biodiversity.ipynb is a blank file and should be used to create your project.
#
# ### Going off platform:
#
# For this particular project, you will be using Jupyter Notebook and Git version control. If you need help with your setup, read our articles about getting started off platform:
#
# + [Command Line Interface Setup](https://www.codecademy.com/articles/command-line-setup)
# + [Introducing Jupyter Notebook](https://www.codecademy.com/articles/introducing-jupyter-notebook)
# + [Setting up Jupyter Notebook](https://www.codecademy.com/articles/setting-up-jupyter-notebook)
# + [Getting Started with Jupyter](https://www.codecademy.com/articles/getting-started-with-jupyter)
# + [Getting More out of Jupyter Notebook](https://www.codecademy.com/articles/getting-more-out-of-jupyter-notebook)
#
# If you need a refresher on how to work with Git for version control, review the [GitHub Desktop article](https://codecademy.com/articles/what-is-git-and-github-desktop) and additional help on this [Git cheat sheet](https://education.github.com/git-cheat-sheet-education.pdf).
#
# [Table of Contents](#Table_of_Contents)

# %% [markdown]
# <a id='Resources'></a>

# %% [markdown]
# ## 3. Resources
#
# ### Debugging Tips + Helpful Resources
#
# Feeling stuck? Try the following:
#
# + Google your question: oftentimes, someone has had the same question as you! Check out websites like [StackOverflow](https://stackoverflow.com/) and [Dev.to](https://dev.to/) to see how other folks have found solutions.
# + Read the documentation: make sure to carefully read through the documentation for any languages and libraries that you are using. Oftentimes they’ll have examples of what you’re looking for!
# + Rubber ducking: try to explain a problem to a friend or co-worker. Oftentimes you’ll figure out the solution as you’re trying to explain it. And if not, getting another pair of eyes on your code can be helpful.
#
# ### Check out these helpful resources:
#
# + [Matplotlib tutorial](https://matplotlib.org/tutorials/introductory/pyplot.html)
# + [Seaborn examples](https://seaborn.pydata.org/examples/index.html)
# + [NumPy tutorial](https://numpy.org/doc/stable/user/quickstart.html)
# + [pandas user guide](https://pandas.pydata.org/docs/user_guide/10min.html)
#
# ### Example Code
#
# What to see an example of how someone else has completed this project? Click [this link](https://content.codecademy.com/PRO/paths/data-science/OKCupid-Date-A-Scientist-Solution.zip) to download a zip file containing one example solution to this project. Remember: your project doesn’t have to look anything like this! It should be unique to your vision.
#
# [Table of Contents](#Table_of_Contents)

# %% [markdown]
# <a id='Project_Tasks'></a>

# %% [markdown]
# ## Project Tasks
# Keep track of your progress by dragging each task from "To Do" to "In Progress" to "Done" as you work on them. You can also click on a task to see more information about it.

# %% [markdown]
# <a id='Project_Setup'></a>

# %% [markdown]
# ### Project Setup
#
# First we will have to download our materials.
#
# 1. Download the [Date-A-Scientist project zip folder](https://content.codecademy.com/PRO/paths/data-science/OKCupid-Date-A-Scientist-Starter.zip).
# 2. Double-click on it to “unzip” the folder. It should contain two items:
#
#     + **date-a-scientist.ipnyb**
#     + **profiles.csv**<br><br>
#
# 3. Type the following into the command line:
#
#     <span style='background: #D3D3D3'> jupyter notebook</span>
#
#     This should open a browser tab.
# 4. Click on **date-a-scientist.ipnyb** in the browser tab. This will open up your Jupyter Notebook.
# 5. Build your project in this file.
#
# #### Hint
#
# [How to Use Jupyter Notebook](https://www.codecademy.com/articles/how-to-use-jupyter-notebooks-py3)
#
# [Table of Contents](#Table_of_Contents)

# %% [markdown]
# <a id='Setting_up_your_Git_Repository'></a>

# %% [markdown]
# ### Setting up your Git Repository
#
# Create a new Git repository for this project.
#
# #### Hint
# If you need more guidance, review the [GitHub Desktop article](https://codecademy.com/articles/what-is-git-and-github-desktop) and additional help on this [Git cheat sheet](https://education.github.com/git-cheat-sheet-education.pdf).
#
# Main components that you will want to include:
#
# + Jupyter Notebook
# + CSV data file(s)
#
# [Table of Contents](#Table_of_Contents)

# %% [markdown]
# <a id='Project_Scoping'></a>

# %% [markdown]
# ## Project Scoping
#
# Properly scoping your project will greatly benefit you; scoping creates structure while requiring you to think through your entire project before you begin. You should start with stating the goals for your project, then gathering the data, and considering the analytical steps required. A proper project scope can be a great road map for your project, but keep in mind that some down-stream tasks may become dead ends which will require adjustment to the scope. image
#
# Here is University of Chicago’s [Data Science Project Scoping Guide](#http://www.datasciencepublicpolicy.org/home/resources/data-science-project-scoping-guide/).
#
# [Table of Contents](#Table_of_Contents)

# %% [markdown]
# <a id='Select_ML-Solvable_Problem'></a>

# %% [markdown]
# ### Select ML-Solvable Problem
#
# First select a problem that you can answer using a machine learning approach. Make sure that this problem can be solved in a reasonable amount of time and with available data. Also, if the problem is too complex, it might be worth breaking it down into smaller units.
#
# Given the columns in the dataset, you could, for example, classify Zodiac signs using drinking, smoking, drugs, and essays as the features.
#
# #### Hint
# Here is a Google guide for [identifying good problems for ML](https://developers.google.com/machine-learning/problem-framing/good).
#
# Main components that you want figured out:
#
# + Problem: e.g., Zodiac symbols are important for many users, but some users don’t add them in.
# + How ML will be used: e.g., Let’s see if there are important variables that can predict a user’s zodiac signs so we can guess the missing zodiacs when we make matches.
#
# [Table of Contents](#Table_of_Contents)

# %% [markdown]
# <a id='Load_and_Check_Data'></a>

# %% [markdown]
# ### Load and Check Data
#
# If supervised learning will be used, check that the data has a label or response variable. If the data is missing a crucial piece for analysis, go back to the previous step to select a different problem to solve.
#
# #### Hint
# The data is stored in profiles.csv. The dataset provided has the following columns of multiple-choice data:
#
# + **body_type**
# + **diet**
# + **drinks**
# + **drugs**
# + **education**
# + **ethnicity**
# + **height**
# + **income**
# + **job**
# + **offspring**
# + **orientation**
# + **pets**
# + **religion**
# + **sex**
# + **sign**
# + **smokes**
# + **speaks**
# + **status**
#
# And a set of open short-answer responses to :
#
# + **essay0** - *My self-summary*
# + **essay1** - *What I’m doing with my life*
# + **essay2** - *I’m really good at…*
# + **essay3** - *The first thing people usually notice about me…*
# + **essay4** - *Favorite books, movies, show, music, and food*
# + **essay5** - *The six things I could never do without*
# + **essay6** - *I spend a lot of time thinking about…*
# + **essay7** - *On a typical Friday night I am…*
# + **essay8** - *The most private thing I am willing to admit*
# + **essay9** - *You should message me if…*
#
# Read over the [pandas read_csv documentation](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_csv.html) for a refresher on how to load and look at the dataset.
#
# [Table of Contents](#Table_of_Contents)

# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
# Import standard libraries.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Set standard pandas options.
pd.set_option("display.max_rows", 2)
pd.options.display.float_format = '{:,.0f}'.format
pd.options.display.precision = 5

# %matplotlib inline
plt.rcParams['figure.figsize'] = (18, 7)

# Change graphs to SVG only if you don't have a lot of points/lines.
# %config InlineBacken2d.figure_formats = ['svg']

# %%
# Load the csv data and import them into pandas DataFrames.
df = pd.DataFrame(pd.read_csv(r'D:\Docs\Private\Educational\Data Visualization\Codeacademy\Projects\18. Machine Learning Portfolio Project\Starter Files\profiles.csv'))

# %% [markdown]
# <a id='Explore_and_Explain_Data'></a>

# %% [markdown]
# ### Explore and Explain Data
#
# Once you have your data, it’s a good idea to get acquainted with it. You should show some summary statistics and visually examine your data. Don’t forget to write out some insights that you have gained along with your analysis.
#
# #### Hint
#
# You can start to build graphs from the data by first importing [Matplotlib](https://matplotlib.org/tutorials/introductory/pyplot.html) or [seaborn](https://seaborn.pydata.org/introduction.html) and then making some plots!<br>
# You can also take a look at what possible responses there are, and the number of times each response was given using pandas value_counts.<br>
# Here is The National Institute of Standards and Technology’s (NIST) [EDA Introduction](https://www.itl.nist.gov/div898/handbook/eda/section1/eda11.htm).<br>
# Main components that you will want to include:<br>
# + Descriptive statistics like mean, median, range, correlations
# + Data visualizations for univariate and multivariate exploration
# + Text explaining insights gained from exploration
#
# [Table of Contents](#Table_of_Contents)

# %%
# View the column names of the dataframe.
df.head(0).style.hide_index()
# Out:
# <style  type="text/css" >
# </style><table id="T_769cbe3e_5987_11eb_98ce_18d6c70734ca" ><thead>    <tr>        <th class="col_heading level0 col0" >age</th>        <th class="col_heading level0 col1" >body_type</th>        <th class="col_heading level0 col2" >diet</th>        <th class="col_heading level0 col3" >drinks</th>        <th class="col_heading level0 col4" >drugs</th>        <th class="col_heading level0 col5" >education</th>        <th class="col_heading level0 col6" >essay0</th>        <th class="col_heading level0 col7" >essay1</th>        <th class="col_heading level0 col8" >essay2</th>        <th class="col_heading level0 col9" >essay3</th>        <th class="col_heading level0 col10" >essay4</th>        <th class="col_heading level0 col11" >essay5</th>        <th class="col_heading level0 col12" >essay6</th>        <th class="col_heading level0 col13" >essay7</th>        <th class="col_heading level0 col14" >essay8</th>        <th class="col_heading level0 col15" >essay9</th>        <th class="col_heading level0 col16" >ethnicity</th>        <th class="col_heading level0 col17" >height</th>        <th class="col_heading level0 col18" >income</th>        <th class="col_heading level0 col19" >job</th>        <th class="col_heading level0 col20" >last_online</th>        <th class="col_heading level0 col21" >location</th>        <th class="col_heading level0 col22" >offspring</th>        <th class="col_heading level0 col23" >orientation</th>        <th class="col_heading level0 col24" >pets</th>        <th class="col_heading level0 col25" >religion</th>        <th class="col_heading level0 col26" >sex</th>        <th class="col_heading level0 col27" >sign</th>        <th class="col_heading level0 col28" >smokes</th>        <th class="col_heading level0 col29" >speaks</th>        <th class="col_heading level0 col30" >status</th>    </tr></thead><tbody>
#         </tbody></table>

# %%
# Rename the columns for the benefit of visualization.
df.columns = [column.capitalize() for column in df.columns]
df.columns = [column.replace('_', ' ').title() for column in df.columns]

# %%
# Views size of the dataframe.
pd.DataFrame({'No. Rows': [len(df)], 'No. Columns': [len(df.columns)]}).style.hide_index()
# Out:
# <style  type="text/css" >
# </style><table id="T_88e860f2_599e_11eb_ae04_18d6c70734ca" ><thead>    <tr>        <th class="col_heading level0 col0" >No. Rows</th>        <th class="col_heading level0 col1" >No. Columns</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_88e860f2_599e_11eb_ae04_18d6c70734carow0_col0" class="data row0 col0" >59946</td>
#                         <td id="T_88e860f2_599e_11eb_ae04_18d6c70734carow0_col1" class="data row0 col1" >31</td>
#             </tr>
#     </tbody></table>

# %%
# Inspect dataframe data types.
dt = pd.DataFrame(df.dtypes).reset_index()
dt.columns = ['Column Name', 'Data Type']
dt.style.hide_index()
# Out:
# <style  type="text/css" >
# </style><table id="T_892f9d35_599e_11eb_bbbb_18d6c70734ca" ><thead>    <tr>        <th class="col_heading level0 col0" >Column Name</th>        <th class="col_heading level0 col1" >Data Type</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_892f9d35_599e_11eb_bbbb_18d6c70734carow0_col0" class="data row0 col0" >Age</td>
#                         <td id="T_892f9d35_599e_11eb_bbbb_18d6c70734carow0_col1" class="data row0 col1" >int64</td>
#             </tr>
#             <tr>
#                                 <td id="T_892f9d35_599e_11eb_bbbb_18d6c70734carow1_col0" class="data row1 col0" >Body Type</td>
#                         <td id="T_892f9d35_599e_11eb_bbbb_18d6c70734carow1_col1" class="data row1 col1" >object</td>
#             </tr>
#             <tr>
#                                 <td id="T_892f9d35_599e_11eb_bbbb_18d6c70734carow2_col0" class="data row2 col0" >Diet</td>
#                         <td id="T_892f9d35_599e_11eb_bbbb_18d6c70734carow2_col1" class="data row2 col1" >object</td>
#             </tr>
#             <tr>
#                                 <td id="T_892f9d35_599e_11eb_bbbb_18d6c70734carow3_col0" class="data row3 col0" >Drinks</td>
#                         <td id="T_892f9d35_599e_11eb_bbbb_18d6c70734carow3_col1" class="data row3 col1" >object</td>
#             </tr>
#             <tr>
#                                 <td id="T_892f9d35_599e_11eb_bbbb_18d6c70734carow4_col0" class="data row4 col0" >Drugs</td>
#                         <td id="T_892f9d35_599e_11eb_bbbb_18d6c70734carow4_col1" class="data row4 col1" >object</td>
#             </tr>
#             <tr>
#                                 <td id="T_892f9d35_599e_11eb_bbbb_18d6c70734carow5_col0" class="data row5 col0" >Education</td>
#                         <td id="T_892f9d35_599e_11eb_bbbb_18d6c70734carow5_col1" class="data row5 col1" >object</td>
#             </tr>
#             <tr>
#                                 <td id="T_892f9d35_599e_11eb_bbbb_18d6c70734carow6_col0" class="data row6 col0" >Essay0</td>
#                         <td id="T_892f9d35_599e_11eb_bbbb_18d6c70734carow6_col1" class="data row6 col1" >object</td>
#             </tr>
#             <tr>
#                                 <td id="T_892f9d35_599e_11eb_bbbb_18d6c70734carow7_col0" class="data row7 col0" >Essay1</td>
#                         <td id="T_892f9d35_599e_11eb_bbbb_18d6c70734carow7_col1" class="data row7 col1" >object</td>
#             </tr>
#             <tr>
#                                 <td id="T_892f9d35_599e_11eb_bbbb_18d6c70734carow8_col0" class="data row8 col0" >Essay2</td>
#                         <td id="T_892f9d35_599e_11eb_bbbb_18d6c70734carow8_col1" class="data row8 col1" >object</td>
#             </tr>
#             <tr>
#                                 <td id="T_892f9d35_599e_11eb_bbbb_18d6c70734carow9_col0" class="data row9 col0" >Essay3</td>
#                         <td id="T_892f9d35_599e_11eb_bbbb_18d6c70734carow9_col1" class="data row9 col1" >object</td>
#             </tr>
#             <tr>
#                                 <td id="T_892f9d35_599e_11eb_bbbb_18d6c70734carow10_col0" class="data row10 col0" >Essay4</td>
#                         <td id="T_892f9d35_599e_11eb_bbbb_18d6c70734carow10_col1" class="data row10 col1" >object</td>
#             </tr>
#             <tr>
#                                 <td id="T_892f9d35_599e_11eb_bbbb_18d6c70734carow11_col0" class="data row11 col0" >Essay5</td>
#                         <td id="T_892f9d35_599e_11eb_bbbb_18d6c70734carow11_col1" class="data row11 col1" >object</td>
#             </tr>
#             <tr>
#                                 <td id="T_892f9d35_599e_11eb_bbbb_18d6c70734carow12_col0" class="data row12 col0" >Essay6</td>
#                         <td id="T_892f9d35_599e_11eb_bbbb_18d6c70734carow12_col1" class="data row12 col1" >object</td>
#             </tr>
#             <tr>
#                                 <td id="T_892f9d35_599e_11eb_bbbb_18d6c70734carow13_col0" class="data row13 col0" >Essay7</td>
#                         <td id="T_892f9d35_599e_11eb_bbbb_18d6c70734carow13_col1" class="data row13 col1" >object</td>
#             </tr>
#             <tr>
#                                 <td id="T_892f9d35_599e_11eb_bbbb_18d6c70734carow14_col0" class="data row14 col0" >Essay8</td>
#                         <td id="T_892f9d35_599e_11eb_bbbb_18d6c70734carow14_col1" class="data row14 col1" >object</td>
#             </tr>
#             <tr>
#                                 <td id="T_892f9d35_599e_11eb_bbbb_18d6c70734carow15_col0" class="data row15 col0" >Essay9</td>
#                         <td id="T_892f9d35_599e_11eb_bbbb_18d6c70734carow15_col1" class="data row15 col1" >object</td>
#             </tr>
#             <tr>
#                                 <td id="T_892f9d35_599e_11eb_bbbb_18d6c70734carow16_col0" class="data row16 col0" >Ethnicity</td>
#                         <td id="T_892f9d35_599e_11eb_bbbb_18d6c70734carow16_col1" class="data row16 col1" >object</td>
#             </tr>
#             <tr>
#                                 <td id="T_892f9d35_599e_11eb_bbbb_18d6c70734carow17_col0" class="data row17 col0" >Height</td>
#                         <td id="T_892f9d35_599e_11eb_bbbb_18d6c70734carow17_col1" class="data row17 col1" >float64</td>
#             </tr>
#             <tr>
#                                 <td id="T_892f9d35_599e_11eb_bbbb_18d6c70734carow18_col0" class="data row18 col0" >Income</td>
#                         <td id="T_892f9d35_599e_11eb_bbbb_18d6c70734carow18_col1" class="data row18 col1" >int64</td>
#             </tr>
#             <tr>
#                                 <td id="T_892f9d35_599e_11eb_bbbb_18d6c70734carow19_col0" class="data row19 col0" >Job</td>
#                         <td id="T_892f9d35_599e_11eb_bbbb_18d6c70734carow19_col1" class="data row19 col1" >object</td>
#             </tr>
#             <tr>
#                                 <td id="T_892f9d35_599e_11eb_bbbb_18d6c70734carow20_col0" class="data row20 col0" >Last Online</td>
#                         <td id="T_892f9d35_599e_11eb_bbbb_18d6c70734carow20_col1" class="data row20 col1" >object</td>
#             </tr>
#             <tr>
#                                 <td id="T_892f9d35_599e_11eb_bbbb_18d6c70734carow21_col0" class="data row21 col0" >Location</td>
#                         <td id="T_892f9d35_599e_11eb_bbbb_18d6c70734carow21_col1" class="data row21 col1" >object</td>
#             </tr>
#             <tr>
#                                 <td id="T_892f9d35_599e_11eb_bbbb_18d6c70734carow22_col0" class="data row22 col0" >Offspring</td>
#                         <td id="T_892f9d35_599e_11eb_bbbb_18d6c70734carow22_col1" class="data row22 col1" >object</td>
#             </tr>
#             <tr>
#                                 <td id="T_892f9d35_599e_11eb_bbbb_18d6c70734carow23_col0" class="data row23 col0" >Orientation</td>
#                         <td id="T_892f9d35_599e_11eb_bbbb_18d6c70734carow23_col1" class="data row23 col1" >object</td>
#             </tr>
#             <tr>
#                                 <td id="T_892f9d35_599e_11eb_bbbb_18d6c70734carow24_col0" class="data row24 col0" >Pets</td>
#                         <td id="T_892f9d35_599e_11eb_bbbb_18d6c70734carow24_col1" class="data row24 col1" >object</td>
#             </tr>
#             <tr>
#                                 <td id="T_892f9d35_599e_11eb_bbbb_18d6c70734carow25_col0" class="data row25 col0" >Religion</td>
#                         <td id="T_892f9d35_599e_11eb_bbbb_18d6c70734carow25_col1" class="data row25 col1" >object</td>
#             </tr>
#             <tr>
#                                 <td id="T_892f9d35_599e_11eb_bbbb_18d6c70734carow26_col0" class="data row26 col0" >Sex</td>
#                         <td id="T_892f9d35_599e_11eb_bbbb_18d6c70734carow26_col1" class="data row26 col1" >object</td>
#             </tr>
#             <tr>
#                                 <td id="T_892f9d35_599e_11eb_bbbb_18d6c70734carow27_col0" class="data row27 col0" >Sign</td>
#                         <td id="T_892f9d35_599e_11

# %%
# Verify the existence of duplicate values.
df[df.duplicated()].style.hide_index()
# Out:
# <style  type="text/css" >
# </style><table id="T_89b2f327_599e_11eb_a732_18d6c70734ca" ><thead>    <tr>        <th class="col_heading level0 col0" >Age</th>        <th class="col_heading level0 col1" >Body Type</th>        <th class="col_heading level0 col2" >Diet</th>        <th class="col_heading level0 col3" >Drinks</th>        <th class="col_heading level0 col4" >Drugs</th>        <th class="col_heading level0 col5" >Education</th>        <th class="col_heading level0 col6" >Essay0</th>        <th class="col_heading level0 col7" >Essay1</th>        <th class="col_heading level0 col8" >Essay2</th>        <th class="col_heading level0 col9" >Essay3</th>        <th class="col_heading level0 col10" >Essay4</th>        <th class="col_heading level0 col11" >Essay5</th>        <th class="col_heading level0 col12" >Essay6</th>        <th class="col_heading level0 col13" >Essay7</th>        <th class="col_heading level0 col14" >Essay8</th>        <th class="col_heading level0 col15" >Essay9</th>        <th class="col_heading level0 col16" >Ethnicity</th>        <th class="col_heading level0 col17" >Height</th>        <th class="col_heading level0 col18" >Income</th>        <th class="col_heading level0 col19" >Job</th>        <th class="col_heading level0 col20" >Last Online</th>        <th class="col_heading level0 col21" >Location</th>        <th class="col_heading level0 col22" >Offspring</th>        <th class="col_heading level0 col23" >Orientation</th>        <th class="col_heading level0 col24" >Pets</th>        <th class="col_heading level0 col25" >Religion</th>        <th class="col_heading level0 col26" >Sex</th>        <th class="col_heading level0 col27" >Sign</th>        <th class="col_heading level0 col28" >Smokes</th>        <th class="col_heading level0 col29" >Speaks</th>        <th class="col_heading level0 col30" >Status</th>    </tr></thead><tbody>
#         </tbody></table>

# %%
# Verify the existance of NaN values.
pd.DataFrame(df.isna().any(), columns=['Presence of NaN values']).transpose()
# Out:
#                           Age  Body Type  Diet  Drinks  Drugs  Education  \
# Presence of NaN values  False       True  True    True   True       True
#
#                         Essay0  Essay1  Essay2  Essay3  ...  Location  \
# Presence of NaN values    True    True    True    True  ...     False
#
#                         Offspring  Orientation  Pets  Religion    Sex  Sign  \
# Presence of NaN values       True        False  True      True  False  True
#
#                         Smokes  Speaks  Status
# Presence of NaN values    True    True   False
#
# [1 rows x 31 columns]

# %%
# Inspect the distribution of NaN values.
pd.DataFrame([df[column].isna().sum() for column in df.columns], columns=['No. NaN values']).set_index(df.columns).transpose()
# Out:
#                 Age  Body Type   Diet  Drinks  Drugs  Education  Essay0  \
# No. NaN values    0       5296  24395    2985  14080       6628    5488
#
#                 Essay1  Essay2  Essay3  ...  Location  Offspring  Orientation  \
# No. NaN values    7572    9638   11476  ...         0      35561            0
#
#                  Pets  Religion  Sex   Sign  Smokes  Speaks  Status
# No. NaN values  19921     20226    0  11056    5512      50       0
#
# [1 rows x 31 columns]

# %%
# Replace the NaN-values with 'Not defined' for further analysis.
nan_df = df.fillna('Not Defined')

# %%
# Create seperate numerical, categorical, open-answer, multiple-choice, ordinal (categorical) and dataframes for quick analsyis.
nr_df = df.select_dtypes(exclude='object').astype('category')
cat_df = df.select_dtypes(include='object').astype('category')
oa_df = df[df.columns[6:16]]
mc_df = cat_df.drop(ess_df.columns, axis=1)
dat_df = df[['Last Online']]
piv_df = df[['Ethnicity']]
ext_df = df[['Offspring', 'Pets', 'Religion', 'Sign']]
ord_df = df[['Drinks', 'Drugs', 'Orientation', 'Sex', 'Smokes', 'Status']]
nord_df = df[['Body Type', 'Diet', 'Job', 'Offspring', 'Pets']]

# %%
df['Offspring'].unique()
# Out:
# array(['doesn&rsquo;t have kids, but might want them', nan,
#        'doesn&rsquo;t want kids',
#        'doesn&rsquo;t have kids, but wants them',
#        'doesn&rsquo;t have kids', 'wants kids', 'has a kid', 'has kids',
#        'doesn&rsquo;t have kids, and doesn&rsquo;t want any',
#        'has kids, but doesn&rsquo;t want more',
#        'has a kid, but doesn&rsquo;t want more',
#        'has a kid, and wants more', 'has kids, and might want more',
#        'might want kids', 'has a kid, and might want more',
#        'has kids, and wants more'], dtype=object)

# %%
# d = {
#     'doesn\'t have kids, but might want them',
#     'doesn\'t want kids',
#     'doesn\'t have kids, but wants them',
#     'doesn\'t have kids',
#     'wants kids',
#     'has a kid',
#     'has kids',
#     'doesn\'t have kids,
#     'doesn\'t want any',
#     'has kids, but doesn\'t  want more',
#     'has a kid, but doesn\'t want more',
#     'has a kid, and wants more',
#     'has kids, and might want more',
#     'might want kids',
#     'has a kid, and might want more',
#     'has kids, and wants more'}
# df['Offspring'] = True if 'ha' in df['Offspring'] else False

# %%
df['Sign'].unique()
# Out:
# array(['gemini', 'cancer', 'pisces but it doesn&rsquo;t matter', 'pisces',
#        'aquarius', 'taurus', 'virgo', 'sagittarius',
#        'gemini but it doesn&rsquo;t matter',
#        'cancer but it doesn&rsquo;t matter',
#        'leo but it doesn&rsquo;t matter', nan,
#        'aquarius but it doesn&rsquo;t matter',
#        'aries and it&rsquo;s fun to think about',
#        'libra but it doesn&rsquo;t matter',
#        'pisces and it&rsquo;s fun to think about', 'libra',
#        'taurus but it doesn&rsquo;t matter',
#        'sagittarius but it doesn&rsquo;t matter',
#        'scorpio and it matters a lot',
#        'gemini and it&rsquo;s fun to think about',
#        'leo and it&rsquo;s fun to think about',
#        'cancer and it&rsquo;s fun to think about',
#        'libra and it&rsquo;s fun to think about',
#        'aquarius and it&rsquo;s fun to think about',
#        'virgo but it doesn&rsquo;t matter',
#        'scorpio and it&rsquo;s fun to think about',
#        'capricorn but it doesn&rsquo;t matter', 'scorpio',
#        'capricorn and it&rsquo;s fun to think about', 'leo',
#        'aries but it doesn&rsquo;t matter', 'aries',
#        'scorpio but it doesn&rsquo;t matter',
#        'sagittarius and it&rsquo;s fun to think about',
#        'libra and it matters a lot',
#        'taurus and it&rsquo;s fun to think about',
#        'leo and it matters a lot',
#        'virgo and it&rsquo;s fun to think about',
#        'cancer and it matters a lot', 'capricorn',
#        'pisces and it matters a lot', 'aries and it matters a lot',
#        'capricorn and it matters a lot', 'aquarius and it matters a lot',
#        'sagittarius and it matters a lot', 'gemini and it matters a lot',
#        'taurus and it matters a lot', 'virgo and it matters a lot'],
#       dtype=object)

# %%
pd.options.display.max_rows = 5

def NoneParser(content):
    if content is None:
        pass
    else:
        return content.split(" ")

test = pd.DataFrame([])
test['Bla'] =  [None, 'Bla die bla', 'Yes']
test['Bla'].apply(lambda x: NoneParser(x))
test['Bla']
# Out:
# 0           None
# 1    Bla die bla
# 2            Yes
# Name: Bla, dtype: object

# %%
# and it matters a lot
# but it doesn't matter
# and it's fun to think about

def NoneParser(content):
    if content is not None:
        return content.split(" ", 1)


df['Sign'] = df['Sign'].astype("string")
df['Sign'].dtypes
df['Sign Value'] = df['Sign'].apply(lambda x: NoneParser(x))
df['Sign Value'].unique()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-185-7b60c2097db1> in <module>
#      10 df['Sign'] = df['Sign'].astype("string")
#      11 df['Sign'].dtypes
# ---> 12 df['Sign Value'] = df['Sign'].apply(lambda x: NoneParser(x))
#      13 df['Sign Value'].unique()
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    4198             else:
#    4199                 values = self.astype(object)._values
# -> 4200                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4201
#    4202         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-185-7b60c2097db1> in <lambda>(x)
#      10 df['Sign'] = df['Sign'].astype("string")
#      11 df['Sign'].dtypes
# ---> 12 df['Sign Value'] = df['Sign'].apply(lambda x: NoneParser(x))
#      13 df['Sign Value'].unique()
#
# <ipython-input-185-7b60c2097db1> in NoneParser(content)
#       5 def NoneParser(content):
#       6     if content is not None:
# ----> 7         return content.split(" ", 1)
#       8
#       9
#
# AttributeError: 'NAType' object has no attribute 'split'

# %%
# from IPython.display import display, HTML 
# for var in cat_df.columns:
#     display(pd.DataFrame([], columns = df[var].unique()).head(1))

# %%
# for col in cat_df.columns[:1]:
#     plt.figure();
#     sns.countplot(x=cat_df[col], data=cat_df, palette='Blues');
#     plt.xticks(rotation=-45);
# #     plt.tick_params(axis='x', labelrotation=-45)
#     plt.title('Histogram of \'{}\'-values\n'.format(col));
#     plt.xticks(ha='left');

# %%
# old_values = pd.DataFrame([])
# column = 'Diet'
# df[column].unique()
# current_values = pd.DataFrame(df[column].unique(), columns=[column])
# old_values = pd.concat([old_values, current_values], ignore_index=True)
# old_values.transpose()

# %%
pd.DataFrame([], columns = df['Drinks'].unique()).head(1)
# Out:
# Empty DataFrame
# Columns: [socially, often, not at all, rarely, nan, very often, desperately]
# Index: []

# %%
pd.DataFrame(df['Drinks'].value_counts()).T
# Out:
#         socially  rarely  often  not at all  very often  desperately
# Drinks     41780    5957   5164        3267         471          322

# %%
df['Drinks'] = pd.Categorical(df['Drinks'], ordered=True, categories=['not at all', 'rarely', 'sociallty', 'often', 'very often', 'desperately'])

# %%
pd.DataFrame([], columns = df['Drugs'].unique()).head(1)
# Out:
# Empty DataFrame
# Columns: [never, sometimes, nan, often]
# Index: []

# %%
pd.DataFrame(df['Drugs'].value_counts()).T
# Out:
#        never  sometimes  often
# Drugs  37724       7732    410

# %%
df['Drugs'] = pd.Categorical(df['Drugs'], ordered=True, categories=['never', 'sometimes', 'often'])

# %%
pd.DataFrame([], columns = df['Smokes'].unique()).head(1)
# Out:
# Empty DataFrame
# Columns: [sometimes, no, nan, when drinking, yes, trying to quit]
# Index: []

# %%
pd.DataFrame(df['Smokes'].value_counts()).T
# Out:
#            no  sometimes  when drinking   yes  trying to quit
# Smokes  43896       3787           3040  2231            1480

# %%
df['Smokes'] = pd.Categorical(df['Smokes'], ordered=True, categories=['no', 'when drinking', 'sometimes', 'tryin to quit', 'yes'])

# %%
pd.DataFrame([], columns = df['Status'].unique()).head(1)
# Out:
# Empty DataFrame
# Columns: [single, available, seeing someone, married, unknown]
# Index: []

# %%
pd.DataFrame(df['Status'].value_counts()).T
# Out:
#         single  seeing someone  available  married  unknown
# Status   55697            2064       1865      310       10

# %%
df['Status'] = pd.Categorical(df['Status'], ordered=True, categories=['single', 'available', 'seeing someone', 'married'])

# %%
df.describe(percentiles = [])
# Out:
#          Age  Height    Income
# count 59,946  59,943    59,946
# mean      32      68    20,033
# std        9       4    97,346
# min       18       1        -1
# 50%       30      68        -1
# max      110      95 1,000,000

# %%
# Visualize countplots for ordinal data.
vars = ['Drinks', 'Drugs', 'Orientation', 'Sex', 'Smokes', 'Status']
len_vars = len(vars)

for i in range(len_vars//3):
    fig, axs = plt.subplots(1, 3, figsize=(10, 4))
    sns.countplot(data=df, x=vars[i * 3 + 0], ax = axs[0], palette='Blues')
    axs[0].set_xticks([])
    axs[0].set_yticks([])
    plt.xticks(rotation=-45);
    axs[0].legend(df[vars[i * 3 + 0]].unique())
    sns.countplot(data=df, x=vars[i * 3 + 1], ax = axs[1], palette='Blues');
    axs[1].set_xticks([])
    axs[1].set_yticks([])
    plt.xticks(rotation=-45);
    axs[1].legend(df[vars[i * 3 + 1]].unique())
    sns.countplot(data=df, x=vars[i * 3 + 2], ax = axs[2], palette='Blues');
    axs[2].set_xticks([])
    axs[2].set_yticks([])
    plt.xticks(rotation=-45);
    axs[2].legend(df[vars[i * 3 + 2]].unique())
    plt.xticks(rotation=-45);

# %%
# Visualize bivariate plots for numerical data
for var in ['Drinks', 'Drugs', 'Orientation', 'Sex', 'Smokes', 'Status']:
    plt.figure();
    sns.pairplot(df, hue=var);
# Out:
# ''

# %% [markdown]
# Men are taller....
# Height is in inches.
# Income is normalized

# %% [markdown]
# <a id='Preprocess_Data'></a>

# %% [markdown]
# ### Preprocess Data
#
# Once you have a good understanding of your data, it is time to get it prepared for modeling. These steps can involve joining data, standardizing variables, removing variables, imputation, and splitting data into train and test sets.
#
# #### Hint
#
# In order to answer the question you’ve formulated, you will probably need to create some new columns in the DataFrame. This is especially true because so much of our data here is categorical (i.e. diet consists of the options vegan, vegetarian, anything, etc. instead of numerical values). Categorical data is great to use as labels, but we want to create some numerical data as well to use for features.
# + [labelEncoder](https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.LabelEncoder.html)
# + [standardization](https://scikit-learn.org/stable/modules/preprocessing.html)
# + [reshaping](https://pandas.pydata.org/pandas-docs/stable/user_guide/reshaping.html)
# + [merge and joining](https://pandas.pydata.org/pandas-docs/stable/user_guide/merging.html)
# + [splitting data](https://scikit-learn.org/stable/modules/classes.html#module-sklearn.model_selection)
#
# Main components that you will want to include:
# + Data ready for modeling
#
# [Table of Contents](#Table_of_Contents)

# %% [markdown]
# <a id='Build_Models'></a>

# %% [markdown]
# ### Build Model(s)
#
# Once the data is preprocessed, it is ready to model. Select the appropriate type(s) of models to solve your problem. Once you have your models, run your data through each model and store your results.
#
#
# #### Hint
#
# Check out the models that are available on scikit learn:
#
# + [Supervised learning models](https://scikit-learn.org/stable/supervised_learning.html)
# + [Unsupervised learning models](https://scikit-learn.org/stable/unsupervised_learning.html)
#
#
# #### Classification
#
# You have learned how to perform classification in a few different ways:
#
# + K-Nearest Neighbors
# + Support Vector Machines
# + Naive Bayes
#
#
# #### Regression
#
# You have learned how to perform regression in a few different ways:
#
# + Multiple Linear Regression
# + K-Nearest Neighbors Regression
#
# Could you apply the techniques you learned to this dataset?
#
# Main components that you will want to include:
#
# + List of models
# + Outputs from models
#
# [Table of Contents](#Table_of_Contents)

# %% [markdown]
# <a id='Evaluate_Models'></a>

# %% [markdown]
# ### Evaluate Model(s)
#
# Once the model(s) are created, you need to use the metric of success that was defined to evaluate the model performance(s). Find the accuracy, precision, and recall of each model you used, and create graphs showing how they changed. If you aren’t satisfied with your results you can repeat the previous step.
#
#
# #### Hint
#
# Some models can be tuned, so if you used default inputs it might be good to take what you learned and redo some of the models.
#
# + [Metrics and scoring](https://scikit-learn.org/stable/modules/model_evaluation.html)
# + [Model selection and evaluation](https://scikit-learn.org/stable/model_selection.html)
# + [Precision-recall](https://scikit-learn.org/stable/auto_examples/model_selection/plot_precision_recall.html)
#
# Main components that you will want to include:
#
# + Table showing model performance
# + Charts showing model performance
#
# [Table of Contents](#Table_of_Contents)

# %% [markdown]
# <a id='Conclusions'></a>

# %% [markdown]
# ### Conclusions
#
# Finally we can wrap up the project. You can write a conclusion about your process and findings.
#
# #### Hint
# Main components that you will want to include:
# + What did you learn through the process?
# + Are the results what you expected?
# + What are the key findings and takeaways?
#
# [Table of Contents](#Table_of_Contents)

# %% [markdown]
# <a id='Next_Steps'></a>

# %% [markdown]
# ### Next Steps
#
# Lastly, being a data scientist is about making continual progress. What are future-looking takeaways and limitations? If you were to do this project again, how could you extend this analysis?
#
#
# #### Hint
#
# Main components that you will want to include:
#
# + Are there things that should be done differently?
# + How can this be used in the future?
#
# [Table of Contents](#Table_of_Contents)

# %% [markdown]
# <a id='Create_a_Slide_Deck'></a>

# %% [markdown]
# ### Create a Slide Deck
#
# Once you’ve performed your analysis, you’re ready to create your slide deck. One of the most important parts of data analysis is being able to communicate your findings.
#
#
# #### Hint
#
# Create a slide deck using [Google Drive](https://drive.google.com/), [Microsoft Powerpoint](https://www.microsoft.com/en-us/microsoft-365/powerpoint), or some other presentation software.
# Your presentation should include the following:
#
# + A title slide
# + A section describing the data in species_info.csv. Be sure to include some (or all) of what you noticed while working through the notebook.
# + A section describing the significance calculations that you did for endangered status between different categories of species.
# + A recommendation for conservationists concerned about endangered species, based on your significance calculations
# + A section describing the sample size determination that you did for the foot and mouth disease study
# + All of the graphs that you created in the notebook
#
# More Resources:
#
# + [How to use Google Slides](https://support.google.com/docs/answer/2763168?co=GENIE.Platform%3DDesktop&hl=en)
# + [Create a presentation in PowerPoint](https://support.microsoft.com/en-us/office/create-a-presentation-in-powerpoint-422250f8-5721-4cea-92cc-202fa7b89617)
#
# [Table of Contents](#Table_of_Contents)
